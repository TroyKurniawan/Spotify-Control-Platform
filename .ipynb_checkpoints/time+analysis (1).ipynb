# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import os
import json
import sys
#import spotipy
import webbrowser
import random
#import spotipy.util as util
import pprint
import subprocess
from json.decoder import JSONDecodeError
import time

# %%
#load data here
songlist=["Shape of you","Despacito","Thats What I Like","Humble."]#small list

# %%
def SelSort(A, B):
    for i in range(len(B)):
        min_index = i
        for j in range(i + 1, len(B)):
            if B[min_index] >= B[j]:
                min_index = j
        A[i], A[min_index] = A[min_index], A[i]
        B[i], B[min_index] = B[min_index], B[i]
        #print(B[min_index])
    return A

# %%
def mergefunc(left, right):
    i = 0
    j = 0
    hold = []

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            hold.append(left[i])
            i += 1
        else:
            hold.append(right[j])
            j += 1
    while i < len(left):
        hold.append(left[i])
        i += 1
    while j < len(right):
        hold.append(right[j])
        j += 1
    return hold


def mergeSort(A):
    n = len(A)
    if n <= 1:
        return A
    left = mergeSort(A[:round(n / 2)])
    right = mergeSort(A[round(n / 2):n])
    return mergefunc(left, right)

# %%
# Shuffle
def shuffle(array, array2):
    n = len(array)
    for i in range(n - 1, 0, -1):
        j = random.randint(0, i)
        array[i], array[j] = array[j], array[i]
        array2[i], array2[j] = array2[j], array2[i]
    return array

# %%
def QS(array, name):
    less = []
    equal = []
    greater = []

    l = []
    e = []
    g = []

    if len(array) > 1 and len(name) > 1:
        pivot = name[0]
        i=0
        for x in name:
            if x < pivot:
                less.append(array[i])
                l.append(x)
            if x == pivot:
                equal.append(array[i])
                e.append(x)
            if x > pivot:
                greater.append(array[i])
                g.append(x)
            i+=1
        return QS(less, l) + equal + QS(greater, g)
    else:
        return array

# %%
# %%timeit #100
A=["SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN"]
QS(A,A)
# Out:
# 471 µs ± 1.07 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit #100
A=["SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN"]
SelSort(A, A)
# Out:
# 753 µs ± 30.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit #100
A=["SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT"]
mergeSort(A)
# Out:
# 6.88 ms ± 34 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit #100
A=["SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT"]
shuffle(A, A,)
# Out:
# 868 µs ± 7.72 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit #200
A=["SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT"]
QS(A, A)
# Out:
# 2.25 ms ± 15 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit #200
A=["SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT"]
SelSort(A, A)
# Out:
# 64.8 ms ± 1.65 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit #200
A=["SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT"]
mergeSort(A)
# Out:
# 6.14 ms ± 15.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit #200
A=["SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT"]
shuffle(A, A)
# Out:
# 1.76 ms ± 22.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit #400
A=["SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT"]
QS(A, A)
# Out:
# 4.4 ms ± 46.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit #400
A=["SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT"]
SelSort(A, A)
# Out:
# 247 ms ± 2.37 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit #400
A=["SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT"]
mergeSort(A)
# Out:
# 13 ms ± 63.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit #400
A=["SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT","PAIN","SHAPE OF YOU","DESPACITO","THATS WHAT I LIKE","HUMBLE.","SOMETHING JUST LIKE THIS","BAD AND BOUJEE","CLOSER","BODY LIKE A BACK ROAD","BELIEVER","CONGRATULATIONS","SAY YOU WONT LET GO","IM THE ONE","XO TOUR LLIF3","MASK OFF","UNFORGETTABLE","24K MAGIC","STAY","WILD THOUGHTS","BLACK BEATLES","STARBOY","LOCATION","ATTENTION","THERES NOTHING HOLDIN ME BACK","BODAK YELLOW","REDBONE","I DONT WANNA LIVE FOREVER","IT AINT ME","ISPY","ISSUES","SCARS TO YOUR BEAUTIFUL","SLOW HANDS","LOVE ON THE BRAIN","I FEEL IT COMING","BOUNCE BACK","STRIP THAT DOWN","FAKE LOVE","DONT WANNA KNOW","LOOK WHAT YOU MADE ME DO","CASTLE ON THE HILL","BAD THINGS","PARIS","SIDE TO SIDE","ROCKABYE","FEEL IT STILL","LET ME LOVE YOU","SORRY NOT SORRY","BANK ACCOUNT","CANT STOP THE FEELING","MI GENTE","THUNDER","T-SHIRT","RAKE IT UP","MERCY","TUNNEL VISION","ROCKSTAR","IN CASE YOU DIDNT KNOW","HEATHENS","NOW OR NEVER","CAROLINE","ROLEX","DNA.","JUJU ON THAT BEAT","SWANG","PASSIONFRUIT","LOYALTY.","PRAYING","GOOSEBUMPS","COLD","BROCCOLI","SLIDE","WHAT IFS","CHAINED TO THE RHYTHM","FEELS","ALL TIME LOW","HURRICANE","TOO GOOD AT GOODBYES","MAGNOLIA","LOVE GALORE","DROWNING","STARVING","BOTH","WHAT ABOUT US","SWALLA","SLIPPERY","SIGN OF THE TIMES","WATER UNDER THE BRIDGE","MALIBU","DOWN","NO PROMISES","TREAT YOU BETTER","I GET THE BAG","SMALL TOWN BOY","EVERYDAY WE LIT","HAVANA","WHAT LOVERS DO","DO RE MI","LOOK AT ME","THE FIGHTER","RIOT"]
shuffle(A, A)
# Out:
# 3.48 ms ± 11.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
